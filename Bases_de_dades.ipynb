# %% [markdown]
# ### Exercicis amb MySQL
#
# # Exercici 1
# **A partir dels documents adjunts (estructura i dades), crea una base de dades amb MySQL. Mostra les característiques principals de l'esquema creat i explica les diferents taules i variables que hi ha.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Es tracta d'una base de dades relacionals relacionades amb el secor del cine.
#
# Podem veure que aquesta base de dades està contruïda a partir de 5 taules:
#
# * tb_role: rols de les pelis
# 1. role_id->id del rol
# 2. role_name->nom del rol
#
# * tb_person: informació de les persones que han participat en la peli
# 1. person_id->id de la persona
# 2. person name->nom de la persona
# 3. person_country->Nom del pais
# 4. person_dob->Data de neixament
# 5. person_dod->data de mort
# 6. person_parent_id->id d'una persona que és familiar
#
# * tb_genre: generes de les pelis que ens podem trobar
# 1. genre_id->id del genere
# 2. genre_name->nom del genere
#
# * tb_movie: informació general de la peli
# 1. movie_id->id de la peli
# 2. movie_title->nom de la peli
# 3. movie_date->data d'estrtena
# 4. movie_format ->format de la peli
# 5. movie_genre_id->id del genere de la peli
#
# * tb_movie_person: taula que relaciona la persona amb la peli en la que ha  treballat
# 1. movie_id->id de la peli
# 2. person_id->id de la persona
# 3. role_id->id del rol
# 4. movie_award_ind->Va rebre premi?(bool)
#
# A més, cada una de les taules te variables més:
# 1. created_by_user->usuari que ha creat la instància
# 2. created_date->data que ha estat creada
# 3. update_date->data que ha estat modificada
#
# En la figura de a dalt podem veure les reslacions que s'estableixen entre elles.

# %% [markdown]
# # Exercici 2
# **Realitza la següent consulta sobre la base de dades acabada de crear:**
#
# **Has d'obtenir el nom, el país i la data de naixement d'aquelles persones per les quals no consti una data de mort i ordenar les dades de la persona més vella a la persona més jove**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercici 3
#
# **Realitza la següent consulta sobre la base de dades acabada de crear:**
#
# **Has d'obtenir el nom del gènere i el nombre total de pel·lícules d'aquest gènere i ordenar-ho per ordre descendent de nombre total de pel·lícules.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercici 4
#
# **Realitza la següent consulta sobre la base de dades acabada de crear:**
#
# **Has d'obtenir, per a cada persona, el seu nom i el nombre màxim de rols diferents que ha tingut en una mateixa pel·lícula.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Posteriorment, mostra únicament aquelles persones que hagin assumit més d'un rol en una mateixa pel·lícula.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercici 5
#
# **Realitza la següent operació sobre la base de dades acabada de crear:**
#
# **Has de crear un nou gènere anomenat "Documental" el qual tingui com a identificador el nombre 69.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercici 6
# **Fes la següent operació sobre la base de dades acabada de crear:**
#
# **Elimina la pel·lícula "La Gran Familia Española" de la base de dades.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Exercici 7
#
# **Realitza la següent operació sobre la base de dades acabada de crear:**
#
# **Canvia el gènere de la pel·lícula "Ocho apellidos catalanes" perquè consti com a comèdia i no com a romàntica.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
